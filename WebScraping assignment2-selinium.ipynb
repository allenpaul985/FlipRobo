# %%
# !pip install selenium

# %%
#importing all the required libraries
import selenium
import pandas as pd
from selenium import webdriver
from time import sleep
from selenium.common.exceptions import NoSuchElementException   # importing Exemption

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
driver=webdriver.Chrome(r"C:\Users\allen\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.

# %%
url='https://www.naukri.com/'
driver.get(url)

# %%
search_job=driver.find_element_by_id('qsb-keyword-sugg')
search_job #keyword search bar
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2f04a440fc7dcef0cacd354782e1896f", element="53c113be-2459-4fd8-baad-e68df0d31bc0")>

# %%
search_job.send_keys("Data Analyst") #enter "Data Analyst" keyword search bar

# %%
search_loc=driver.find_element_by_id('qsb-location-sugg')
search_loc #location search bar
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2f04a440fc7dcef0cacd354782e1896f", element="9279ba65-51c3-4dc8-a864-3dcfa9ef0d8c")>

# %%
search_loc.send_keys("Bangalore") #enters 'Bangalore' in location search bar

# %%
search_btn=driver.find_element_by_xpath("//button[@class='btn']")
search_btn.click() #clicks on search button

# %%
job_title_tags=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")

# %%
job_title=[]
for i in job_title_tags:
    if len(job_title)<10:
        job_title.append(i.text)

job_title = pd.DataFrame(job_title)
job_title.columns=['Job_title']
job_title
#Job titles of first 10 jobs in Bangolore
# Out:
#                                                              Job_title
# 0  Data Scientist / Data Analyst -Business Analyst
# 1  Hiring Data Analysts For E commerce Platform || WFH
# 2  Data Analyst
# 3  Data Analyst
# 4  Hiring For Data Analyst/ MIS Reporting Analyst - Bangalore
# 5  DA - Urgent Opening For Data Analyst BFSI Domain - Pan India
# 6  Data Analyst - Informatica MDM
# 7  Data Analyst
# 8  Assistant Vice President - MIS & Reporting ( Business Data Analyst)
# 9  Data Analyst

# %%
job_location_tags=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']")

# %%
pd.set_option("display.max_colwidth", -1) #displays whole column value

# %%
job_location=[]
for i in job_location_tags:
    if len(job_location)<10:
        job_location.append(i.text)

job_location = pd.DataFrame(job_location)
job_location.columns=['Job_location']
job_location
#Job Locations of first 10 jobs in Bangolore
# Out:
#                                                                                                       Job_location
# 0  Mumbai, Hyderabad/Secunderabad, Pune, Gurgaon/Gurugram, Chennai, Bangalore/Bengaluru
# 1  Bangalore/Bengaluru
# 2  Bangalore/Bengaluru
# 3  Bangalore/Bengaluru
# 4  Bangalore/Bengaluru
# 5  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedabad, Chennai, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)
# 6  Bangalore/Bengaluru
# 7  Bangalore/Bengaluru
# 8  Mumbai, Bangalore/Bengaluru
# 9  Bangalore/Bengaluru

# %%
company_name_tags=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")

# %%
company_name=[]
for i in company_name_tags:
    if len(company_name)<10:
        company_name.append(i.text)

company_name = pd.DataFrame(company_name)
company_name.columns=['Company_name']
company_name
#Company names of first 10 jobs in Bangolore
# Out:
#                                              Company_name
# 0  Inflexion Analytix Private Limited
# 1  Allegis Services India Pvt. Ltd.
# 2  Shell India Markets Private Limited
# 3  Applied Materials
# 4  PHARMACEUTICAL RESEARCH ASSOCIATES INDIA Pvt Ltd
# 5  Tata Consultancy Services Ltd.
# 6  Shell India Markets Private Limited
# 7  Shell India Markets Private Limited
# 8  INTERTRUSTVITEOS CORPORATE AND FUND SERVICES PVT. LTD.
# 9  Myntra Designs Pvt. Ltd.

# %%
experience_required_tags=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']")

# %%
experience_required=[]
for i in experience_required_tags:
    if len(experience_required)<10:
        experience_required.append(i.text)

experience_required = pd.DataFrame(experience_required)
experience_required.columns=['Experience_required']
experience_required
#Experience required of first 10 jobs in Bangolore
# Out:
#   Experience_required
# 0  0-3 Yrs
# 1  0-5 Yrs
# 2  5-8 Yrs
# 3  7-10 Yrs
# 4  2-4 Yrs
# 5  4-9 Yrs
# 6  6-9 Yrs
# 7  5-8 Yrs
# 8  12-18 Yrs
# 9  3-6 Yrs

# %%
First10jobresults=pd.DataFrame({})
First10jobresults['Job_title']=job_title['Job_title']
First10jobresults['Job_location']=job_location['Job_location']
First10jobresults['Company_name']=company_name['Company_name']
First10jobresults['Experience_required']=experience_required['Experience_required']
First10jobresults
#first 10 job-title, job-location, company_name, experience_require for 'Data Analyst' Job position in bangalore
# Out:
#                                                              Job_title  \
# 0  Data Scientist / Data Analyst -Business Analyst
# 1  Hiring Data Analysts For E commerce Platform || WFH
# 2  Data Analyst
# 3  Data Analyst
# 4  Hiring For Data Analyst/ MIS Reporting Analyst - Bangalore
# 5  DA - Urgent Opening For Data Analyst BFSI Domain - Pan India
# 6  Data Analyst - Informatica MDM
# 7  Data Analyst
# 8  Assistant Vice President - MIS & Reporting ( Business Data Analyst)
# 9  Data Analyst
#
#                                                                                                       Job_location  \
# 0  Mumbai, Hyderabad/Secunderabad, Pune, Gurgaon/Gurugram, Chennai, Bangalore/Bengaluru
# 1  Bangalore/Bengaluru
# 2  Bangalore/Bengaluru
# 3  Bangalore/Bengaluru
# 4  Bangalore/Bengaluru
# 5  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedabad, Chennai, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)
# 6  Bangalore/Bengaluru
# 7  Bangalore/Bengaluru
# ...

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, full job-description. You have to scrape first 10 jobs data.

# %%
driver=webdriver.Chrome("chromedriver.exe")
url='https://www.naukri.com/'
driver.get(url)

# %%
search_job1=driver.find_element_by_id('qsb-keyword-sugg')
search_job1 # keyowrd search bar
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="3f1dbddc5ddb0a6e75b9200ed9c484a6", element="3063b97b-4b18-4cf5-be84-b5c2d353bc96")>

# %%
search_job1.send_keys("Data Scientist") #enters'Data Scientist' in keyword search bar

# %%
search_loc1=driver.find_element_by_id('qsb-location-sugg')
search_loc1 # location search bar
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="3f1dbddc5ddb0a6e75b9200ed9c484a6", element="9ba6161f-5c56-42de-a1e0-c9e9351ca490")>

# %%
search_loc1.send_keys("Bangalore") #enters'Bangalore' in location search bar

# %%
search_btn1=driver.find_element_by_xpath("//button[@class='btn']")
search_btn1.click() #clicks on search button

# %%
job_title_tags1=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")

# %%
job_title1=[]
for i in job_title_tags1:
    if len(job_title1)<10:
        job_title1.append(i.text)

job_title1 = pd.DataFrame(job_title1)
job_title1.columns=['Job_title']
job_title1
#Job titles of first 10 jobs in Bangolore
# Out:
#                                                     Job_title
# 0  Data Scientist / Data Analyst -Business Analyst
# 1  Data Scientist
# 2  Big Data - Data Scientist
# 3  Specialist I - Data Scientist
# 4  Lead Data Scientist
# 5  Data Scientist
# 6  SDE Lead Data Scientist-L3
# 7  Computational Design Lead Data Scientist-L3
# 8  Hiring For DATA Scientist - ON Contract Basis (3-6 Months)
# 9  Senior Data Scientist

# %%
job_location_tags1=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']")

# %%
job_location1=[]
for i in job_location_tags1:
    if len(job_location1)<10:
        job_location1.append(i.text)

job_location1 = pd.DataFrame(job_location1)
job_location1.columns=['Job_location']
job_location1
#Job Locations of first 10 jobs in Bangolore
# Out:
#                                                                                              Job_location
# 0  Mumbai, Hyderabad/Secunderabad, Pune, Gurgaon/Gurugram, Chennai, Bangalore/Bengaluru
# 1  Kolkata, Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru
# 2  Kochi/Cochin, Indore, Hyderabad/Secunderabad, Pune, Ahmedabad, Bangalore/Bengaluru, Mumbai (All Areas)
# 3  Bangalore/Bengaluru
# 4  Bangalore/Bengaluru
# 5  Bangalore/Bengaluru
# 6  Bangalore/Bengaluru
# 7  Bangalore/Bengaluru
# 8  Hyderabad/Secunderabad, Bangalore/Bengaluru, Mumbai (All Areas)
# 9  Bangalore/Bengaluru

# %%
company_name_tags1=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")

# %%
company_name1=[]
for i in company_name_tags1:
    if len(company_name1)<10:
        company_name1.append(i.text)

company_name1 = pd.DataFrame(company_name1)
company_name1.columns=['Company_name']
company_name1
#Company names of first 10 jobs in Bangolore
# Out:
#                                          Company_name
# 0  Inflexion Analytix Private Limited
# 1  Wipro Limited
# 2  Xoriant Solutions Pvt Ltd
# 3  Philips India Limited
# 4  Intel Technology India Pvt Ltd
# 5  Oracle India Pvt. Ltd.
# 6  Huawei Technologies India Pvt Ltd
# 7  Huawei Technologies India Pvt Ltd
# 8  GlobalEdx Learning and Technology Solution Pvt Ltd
# 9  GO-JEK India

# %%
experience_required_tags1=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']")

# %%
experience_required1=[]
for i in experience_required_tags1:
    if len(experience_required1)<10:
        experience_required1.append(i.text)

experience_required1 = pd.DataFrame(experience_required1)
experience_required1.columns=['Experience_required']
experience_required1
#Experience required of first 10 jobs in Bangolore
# Out:
#   Experience_required
# 0  0-3 Yrs
# 1  4-9 Yrs
# 2  1-3 Yrs
# 3  4-7 Yrs
# 4  6-10 Yrs
# 5  6-10 Yrs
# 6  5-8 Yrs
# 7  5-8 Yrs
# 8  3-8 Yrs
# 9  4-11 Yrs

# %%
First10jobresultsofdatascientist=pd.DataFrame({})
First10jobresultsofdatascientist['Job_title']=job_title1['Job_title']
First10jobresultsofdatascientist['Job_location']=job_location1['Job_location']
First10jobresultsofdatascientist['Company_name']=company_name1['Company_name']
First10jobresultsofdatascientist['Experience_required']=experience_required1['Experience_required']
First10jobresultsofdatascientist
#first 10 job-title, job-location, company_name, experience_require for 'Data scientist' Job position in bangalore
# Out:
#                                                     Job_title  \
# 0  Data Scientist / Data Analyst -Business Analyst
# 1  Data Scientist
# 2  Big Data - Data Scientist
# 3  Specialist I - Data Scientist
# 4  Lead Data Scientist
# 5  Data Scientist
# 6  SDE Lead Data Scientist-L3
# 7  Computational Design Lead Data Scientist-L3
# 8  Hiring For DATA Scientist - ON Contract Basis (3-6 Months)
# 9  Senior Data Scientist
#
#                                                                                              Job_location  \
# 0  Mumbai, Hyderabad/Secunderabad, Pune, Gurgaon/Gurugram, Chennai, Bangalore/Bengaluru
# 1  Kolkata, Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru
# 2  Kochi/Cochin, Indore, Hyderabad/Secunderabad, Pune, Ahmedabad, Bangalore/Bengaluru, Mumbai (All Areas)
# 3  Bangalore/Bengaluru
# 4  Bangalore/Bengaluru
# 5  Bangalore/Bengaluru
# 6  Bangalore/Bengaluru
# 7  Bangalore/Bengaluru
# 8  Hyderabad/Secunderabad, Bangalore/Bengaluru, Mumbai (All Areas)
# ...

# %%
jobdesc=[] #scraping all urls of first 10 job's full description
for i in driver.find_elements_by_xpath("//div[@class='info fleft']/a"):
    if len(jobdesc)<10:
        jobdesc.append(i.get_attribute('href'))
jobdesc
# Out:
# ['https://www.naukri.com/job-listings-data-scientist-data-analyst-business-analyst-inflexion-analytix-private-limited-mumbai-hyderabad-secunderabad-pune-gurgaon-gurugram-chennai-bangalore-bengaluru-0-to-3-years-100521000368?src=jobsearchDesk&sid=16216937834373910&xp=1&px=1',
#  'https://www.naukri.com/job-listings-data-scientist-wipro-limited-kolkata-hyderabad-secunderabad-chennai-bangalore-bengaluru-4-to-9-years-210521000038?src=jobsearchDesk&sid=16216937834373910&xp=2&px=1',
#  'https://www.naukri.com/job-listings-big-data-data-scientist-xoriant-solutions-pvt-ltd-kochi-cochin-indore-hyderabad-secunderabad-pune-ahmedabad-bangalore-bengaluru-mumbai-all-areas-1-to-3-years-130521005018?src=jobsearchDesk&sid=16216937834373910&xp=3&px=1',
#  'https://www.naukri.com/job-listings-specialist-i-data-scientist-philips-india-limited-bangalore-bengaluru-4-to-7-years-170521500993?src=jobsearchDesk&sid=16216937834373910&xp=4&px=1',
# ...

# %%
len(jobdesc)
# Out:
# 10

# %%
jobdescription=[]
for i in jobdesc:
    url=i
    driver.get(url)
    sleep(4)
    try:
        job=driver.find_element_by_xpath("//div[@class='dang-inner-html']")
        jobdescription.append(job.text.replace('\\n', '\n'))
    except NoSuchElementException:
        job=driver.find_element_by_xpath("//div[@class='clearboth description']")
        jobdescription.append(job.text.replace('\\n', '\n'))
        
    print(jobdescription)
# Out:
# ["Job Role : Data Scientist/Data Analyst /Business Analyst\n\nLocation : Chennai/Bangalore/Hyderabad/Pune/Mumbai/Delhi\n\nGreetings from CAIA - Center for Artificial Intelligence & Advanced Analytics\n43% of companies experienced a high deficit of skilled resources with Advanced Analytical skills and AI implementing capabilities in year 2020. CAIA gives you a great opportunity to enter the world of future technologies and Innovations- Data Science, Analytics, AI, Data Visualization and Cloud Computing.\n\nWhile 2020 was a year like no other, we are living in an interesting times where data is reshaping the world, and businesses are rapidly adopting technology to gain an edge over others. Hence, there's a substantial increase in demand for technology professionals who can implement systems in data science, machine learning and AI in Tier 1 and Tier 2 organization's working closely with us.\n\nTo help you build a sustainable career we would like you to utilize data, software and Analyt
# ...

# %%
jobdescriptions = pd.DataFrame(jobdescription)
jobdescriptions.columns=['Jobdescription']
jobdescriptions
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
jobdescriptions['Jobdescription']=jobdescriptions['Jobdescription'].str.replace('\\n', '\n').replace('\\t', '\t')

# %%
jobdescriptions['Jobdescription']=jobdescriptions['Jobdescription'].str.replace('\n', ' ')

# %%
jobdescriptions
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
First10jobresultsofdatascientist['Full_job_description']=jobdescriptions['Jobdescription']
First10jobresultsofdatascientist
#first 10 job-title, job-location, company_name, experience_require and full job dexcription for 'Data scientist' Job position in bangalore
# Out:
#                                                     Job_title  \
# 0  Data Scientist / Data Analyst -Business Analyst
# 1  Data Scientist
# 2  Big Data - Data Scientist
# 3  Specialist I - Data Scientist
# 4  Lead Data Scientist
# 5  Data Scientist
# 6  SDE Lead Data Scientist-L3
# 7  Computational Design Lead Data Scientist-L3
# 8  Hiring For DATA Scientist - ON Contract Basis (3-6 Months)
# 9  Senior Data Scientist
#
#                                                                                              Job_location  \
# 0  Mumbai, Hyderabad/Secunderabad, Pune, Gurgaon/Gurugram, Chennai, Bangalore/Bengaluru
# 1  Kolkata, Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru
# 2  Kochi/Cochin, Indore, Hyderabad/Secunderabad, Pune, Ahmedabad, Bangalore/Bengaluru, Mumbai (All Areas)
# 3  Bangalore/Bengaluru
# 4  Bangalore/Bengaluru
# 5  Bangalore/Bengaluru
# 6  Bangalore/Bengaluru
# 7  Bangalore/Bengaluru
# 8  Hyderabad/Secunderabad, Bangalore/Bengaluru, Mumbai (All Areas)
# ...

# %% [markdown]
# Q3: In this question you have to scrape data using the filters available on the webpage as shown below:
# You

# %%
driver=webdriver.Chrome("chromedriver.exe")
url='https://www.naukri.com/'
driver.get(url)

# %%
search_job3=driver.find_element_by_id('qsb-keyword-sugg')
search_job3

search_job3.send_keys("Data Scientist")
#enters "Data Scientist" in keyowrd search bar

# %%
search_btn1=driver.find_element_by_xpath("//button[@class='btn']")
search_btn1.click() #clicks on search button

# %%
search_btn2=driver.find_element_by_xpath("(//i[@class='fleft naukicon naukicon-checkbox'])[2]")
search_btn2.click() #clicks on “Delhi/NCR” filter

# %%
search_btn3=driver.find_element_by_xpath("(//i[@class='fleft naukicon naukicon-checkbox'])[5]")
search_btn3.click() #clicks on “3-6” lakhs filter

# %%
job_title_tags2=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")

# %%
job_title2=[]
for i in job_title_tags2:
    if len(job_title2)<10:
        job_title2.append(i.text)

job_title2 = pd.DataFrame(job_title2)
job_title2.columns=['Job_title']
job_title2
#Job titles of first 10 jobs using location filter as “Delhi/NCR” and salary filter as “3-6” lakhs
# Out:
#                                                        Job_title
# 0  Data Scientist / Data Analyst -Business Analyst
# 1  Data Scientist
# 2  Data Scientist - High growth VC backed Influencer Marketplace
# 3  Excellent opportunity For Data Scientist
# 4  Data Scientist
# 5  DATA Scientist – Gurgaon (Exp 3-6 years)
# 6  DATA Scientist – Gurgaon (Exp 3-6 years)
# 7  Data Scientist - Noida
# 8  Data Scientist - Noida/ B'lore
# 9  Data Scientist

# %%
job_location_tags2=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']")

# %%
job_location2=[]
for i in job_location_tags2:
    if len(job_location2)<10:
        job_location2.append(i.text)
job_location2
job_location2 = pd.DataFrame(job_location2)
job_location2.columns=['Job_location']
job_location2
#Job Locations of first 10 jobs using location filter as “Delhi/NCR” and salary filter as “3-6” lakhs
# Out:
#                                                                            Job_location
# 0  Mumbai, Hyderabad/Secunderabad, Pune, Gurgaon/Gurugram, Chennai, Bangalore/Bengaluru
# 1  Noida, Hyderabad/Secunderabad, Bangalore/Bengaluru
# 2  Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)
# 3  Noida, Bangalore/Bengaluru
# 4  New Delhi, Gurgaon/Gurugram, Delhi / NCR
# 5  Gurgaon/Gurugram, Delhi / NCR
# 6  Gurgaon/Gurugram, Delhi / NCR
# 7  Noida
# 8  Noida, Bangalore/Bengaluru
# 9  Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)

# %%
company_name_tags2=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")

# %%
company_name2=[]
for i in company_name_tags2:
    if len(company_name2)<10:
        company_name2.append(i.text)

company_name2 = pd.DataFrame(company_name2)
company_name2.columns=['Company_name']
company_name2
#Company names of first 10 jobs using location filter as “Delhi/NCR” and salary filter as “3-6” lakhs
# Out:
#                                                 Company_name
# 0  Inflexion Analytix Private Limited
# 1  IBM India Pvt. Limited
# 2  Ravgins International Pvt. Ltd.
# 3  NEC CORPORATION INDIA PRIVATE LIMITED
# 4  Mobikwik
# 5  CRESCENDO GLOBAL LEADERSHIP HIRING INDIA PRIVATE L IMITED
# 6  CRESCENDO GLOBAL LEADERSHIP HIRING INDIA PRIVATE L IMITED
# 7  Optum Global Solutions (India) Private Limited
# 8  NEC CORPORATION INDIA PRIVATE LIMITED
# 9  Cloudstrats Technologies Private Limited

# %%
experience_required_tags2=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']")

# %%
experience_required2=[]
for i in experience_required_tags2:
    if len(experience_required2)<10:
        experience_required2.append(i.text)

experience_required2 = pd.DataFrame(experience_required2)
experience_required2.columns=['Experience_required']
experience_required2
#Experience required of first using location filter as “Delhi/NCR” and salary filter as “3-6” lakhs
# Out:
#   Experience_required
# 0  0-3 Yrs
# 1  4-9 Yrs
# 2  3-5 Yrs
# 3  3-7 Yrs
# 4  3-5 Yrs
# 5  3-6 Yrs
# 6  3-6 Yrs
# 7  3-5 Yrs
# 8  3-8 Yrs
# 9  5-8 Yrs

# %%
First10jobresultsofdatascientistindelhi=pd.DataFrame({})
First10jobresultsofdatascientistindelhi['Job_title']=job_title2['Job_title']
First10jobresultsofdatascientistindelhi['Job_location']=job_location2['Job_location']
First10jobresultsofdatascientistindelhi['Company_name']=company_name2['Company_name']
First10jobresultsofdatascientistindelhi['Experience_required']=experience_required2['Experience_required']
First10jobresultsofdatascientistindelhi
# first 10 job-title, job-location, company_name, experience_require for 'Data scientist' Job position in Delhi/NCR,
# with salary of 3-6 lakhs
# Out:
#                                                        Job_title  \
# 0  Data Scientist / Data Analyst -Business Analyst
# 1  Data Scientist
# 2  Data Scientist - High growth VC backed Influencer Marketplace
# 3  Excellent opportunity For Data Scientist
# 4  Data Scientist
# 5  DATA Scientist – Gurgaon (Exp 3-6 years)
# 6  DATA Scientist – Gurgaon (Exp 3-6 years)
# 7  Data Scientist - Noida
# 8  Data Scientist - Noida/ B'lore
# 9  Data Scientist
#
#                                                                            Job_location  \
# 0  Mumbai, Hyderabad/Secunderabad, Pune, Gurgaon/Gurugram, Chennai, Bangalore/Bengaluru
# 1  Noida, Hyderabad/Secunderabad, Bangalore/Bengaluru
# 2  Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)
# 3  Noida, Bangalore/Bengaluru
# 4  New Delhi, Gurgaon/Gurugram, Delhi / NCR
# 5  Gurgaon/Gurugram, Delhi / NCR
# 6  Gurgaon/Gurugram, Delhi / NCR
# 7  Noida
# 8  Noida, Bangalore/Bengaluru
# 9  Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)
# ...

# %% [markdown]
# Q4: Write a python program to scrape data for first 10 job results for Data scientist
# Designation in Noida location. You have to scrape company_name, No. of days
# ago when job was posted, Rating of the company.

# %%
driver=webdriver.Chrome("chromedriver.exe")
url='https://www.glassdoor.co.in/index.htm'
driver.get(url)

# %%
search_job3=driver.find_element_by_xpath("//input[@placeholder='Job Title, Keywords or Company']")
search_job3.click() #clicks on keyword search bar

# %%
# search_job3=driver.find_element_by_xpath("//span[@class='SVGInline d-flex SearchStyles__searchIcon']")
# search_job3.click()

# %%
search_job4=driver.find_element_by_id('scKeyword')
search_job4 #clicks on keyword search bar
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="36df3e7f1ca7a5dc70ec94170b08b5f6", element="1fe2af04-def4-42d0-8938-1afec6fa1fd4")>

# %%
search_job4.send_keys("Data Scientist") #enters "Data Scientist" in search bar

# %%
search_loc4=driver.find_element_by_id('prefix__icon-arrow-1')
search_loc4.click() #clicks on location search bar

# %%
search_loc3=driver.find_element_by_id('sc.location')
search_loc3 #clicks on location search bar
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="36df3e7f1ca7a5dc70ec94170b08b5f6", element="779a2fe7-9247-46a0-9d72-8d6724e012b7")>

# %%
from selenium.webdriver.common.keys import Keys #importing keys

# %%
search_loc3.send_keys(Keys.CONTROL + "a") 
search_loc3.send_keys(Keys.DELETE) #clears location search bar
search_loc3.send_keys("Noida") #enters "Noida" in location search bar

# %%
search_btn3=driver.find_element_by_xpath("//button[@class='gd-ui-button ml-std col-auto SearchStyles__newSearchButton css-iixdfr']")
search_btn3.click() #clicks on search button

# %%
company_name_tags4=driver.find_elements_by_xpath("//a[@class=' css-l2wjgv e1n63ojh0 jobLink']")

# %%
company_name4=[]
for i in company_name_tags4:
    if len(company_name4)<10:
        company_name4.append(i.text)
company_name4
company_name4 = pd.DataFrame(company_name4)
company_name4.columns=['company_name']
company_name4
#company names of first 10 Data Scientists jobs in Noida from glassdoor
# Out:
#                    company_name
# 0                Biz2Credit Inc
# 1                      Techlive
# 2                      Ericsson
# 3                 NatWest Group
# 4  Salasar New Age Technologies
# 5            Apsidata Solutions
# 6                       CRMNEXT
# 7  Salasar New Age Technologies
# 8        Data Trained Education
# 9                     dunnhumby

# %%
days=driver.find_elements_by_xpath("//div[@class='d-flex align-items-end pl-std css-mi55ob']")

# %%
no_of_days=[]
for i in days:
    if len(no_of_days)<10:
        no_of_days.append(i.text)
no_of_days
no_of_days = pd.DataFrame(no_of_days)
no_of_days.columns=['No_of_days']
no_of_days
#No. of days ago when job was posted of first 10 Data Scientists jobs in Noida from glassdoor
# Out:
#   No_of_days
# 0       30d+
# 1       30d+
# 2        13d
# 3        24h
# 4       30d+
# 5         3d
# 6        12d
# 7       30d+
# 8         1d
# 9        24h

# %%
rat=[] #scraping all urls of first 10 job's full description
for i in driver.find_elements_by_xpath("//div[@class='d-flex justify-content-between align-items-start']/a"):
    if len(rat)<10:
        rat.append(i.get_attribute('href'))
rat
# Out:
# ['https://www.glassdoor.co.in/partner/jobListing.htm?pos=101&ao=1136043&s=58&guid=000001798187adfb82f22184bd53cb86&src=GD_JOB_AD&t=SR&vt=w&uido=047932A66C2519CE32EC31CA5D9D071C&ea=1&cs=1_b6832e69&cb=1621375824340&jobListingId=1006687249100&jrtk=1-1f60ofc2su3kk801-1f60ofc3eu2il800-94036c835379de77',
#  'https://www.glassdoor.co.in/partner/jobListing.htm?pos=102&ao=1136043&s=58&guid=000001798187adfb82f22184bd53cb86&src=GD_JOB_AD&t=SR&vt=w&uido=047932A66C2519CE32EC31CA5D9D071C&cs=1_5460cbb7&cb=1621375824339&jobListingId=1006461286442&jrtk=1-1f60ofc2su3kk801-1f60ofc3eu2il800-a1ea358f023a69b7',
#  'https://www.glassdoor.co.in/partner/jobListing.htm?pos=103&ao=1136043&s=58&guid=000001798187adfb82f22184bd53cb86&src=GD_JOB_AD&t=SR&vt=w&uido=047932A66C2519CE32EC31CA5D9D071C&cs=1_f6da4d8b&cb=1621375824339&jobListingId=1007039772952&jrtk=1-1f60ofc2su3kk801-1f60ofc3eu2il800-6bf9c5704a989f4b',
# ...

# %%
rating=[]
for i in rat:
    url=i
    driver.get(url)
    sleep(4)
    try:
        ratings=driver.find_element_by_xpath("//span[@class='css-1pmc6te e11nt52q4']")
        rating.append(ratings.text)
    except NoSuchElementException:
        rating.append('None')

# %%
rating = pd.DataFrame(rating)
rating.columns=['rating']
rating['rating']=rating['rating'].str.replace('\n','')
rating
#Ratings of the company of first 10 Data Scientists jobs in Noida from glassdoor
# Out:
#   rating
# 0   3.8★
# 1   5.0★
# 2   4.1★
# 3   3.9★
# 4   None
# 5   None
# 6   3.6★
# 7   None
# 8   None
# 9   4.1★

# %%
datascientistnoida10=pd.DataFrame({})
datascientistnoida10['Company_name']=company_name4['company_name']
datascientistnoida10['No_of_days_before_job_posted']=no_of_days['No_of_days']
datascientistnoida10['Ratings']=rating['rating']
datascientistnoida10
# 10 job results for Data scientist Designation in Noida location
#scraped company_name, No. of days ago when job was posted, Rating of the company
# Out:
#                    Company_name No_of_days_before_job_posted Ratings
# 0                Biz2Credit Inc                         30d+    3.8★
# 1                      Techlive                         30d+    5.0★
# 2                      Ericsson                          13d    4.1★
# 3                 NatWest Group                          24h    3.9★
# 4  Salasar New Age Technologies                         30d+    None
# 5            Apsidata Solutions                           3d    None
# 6                       CRMNEXT                          12d    3.6★
# 7  Salasar New Age Technologies                         30d+    None
# 8        Data Trained Education                           1d    None
# 9                     dunnhumby                          24h    4.1★

# %% [markdown]
# Q5: Write a python program to scrape the salary data for Data Scientist designation
# in Noida location.

# %%
driver=webdriver.Chrome("chromedriver.exe")
url='https://www.glassdoor.co.in/Salaries/index.htm'
driver.get(url)

# %%
search_job5=driver.find_element_by_id('KeywordSearch')
search_job5.click()#click on keyword search bar

# %%
search_job5.send_keys("Data Scientist")  #entering Data Scientist in keyword search bar

# %%
search_loc5=driver.find_element_by_id('LocationSearch')
search_loc5.click() #click on location search bar

# %%
search_loc5.send_keys("Noida") #entering noida in locationsearch bar

# %%
search_btn1=driver.find_element_by_xpath("//button[@class='gd-btn-mkt']")
search_btn1.click() #clicks on search button

# %%
company_name_tags5=driver.find_elements_by_xpath("//div[@class='d-flex']/div/p[2]")

# %%
company_name5=[]
for i in company_name_tags5:
    if len(company_name5)<10:
        company_name5.append(i.text)
company_name5
company_name5 = pd.DataFrame(company_name5)
company_name5.columns=['company_name']
company_name5
#company names of first 10 Data Scientists jobs in Noida from glassdoor
# Out:
#                 company_name
# 0  Tata Consultancy Services
# 1                  Accenture
# 2                        IBM
# 3         Ericsson-Worldwide
# 4                  Delhivery
# 5         UnitedHealth Group
# 6         Valiance Solutions
# 7              ZS Associates
# 8                EXL Service
# 9     Optum Global Solutions

# %%
min_sal=driver.find_elements_by_xpath("//div[@class='common__RangeBarStyle__values d-flex justify-content-between ']/span[1]")

# %%
min_salary=[]
for i in min_sal:
    if len(min_salary)<10:
        min_salary.append(i.text)
min_salary
min_salary = pd.DataFrame(min_salary)
min_salary.columns=['min_salary']
min_salary
#Minimum salaries of first 10 companies
# Out:
#   min_salary
# 0      ₹343K
# 1      ₹577K
# 2      ₹586K
# 3      ₹355K
# 4      ₹450K
# 5    ₹1,069K
# 6      ₹502K
# 7      ₹202K
# 8      ₹575K
# 9    ₹1,014K

# %%
max_sal=driver.find_elements_by_xpath("//div[@class='common__RangeBarStyle__values d-flex justify-content-between ']/span[2]")

# %%
max_salary=[]
for i in max_sal:
    if len(max_salary)<10:
        max_salary.append(i.text)
max_salary
max_salary = pd.DataFrame(max_salary)
max_salary.columns=['max_salary']
max_salary
#Maximum salaries of first 10 companies
# Out:
#   max_salary
# 0    ₹1,095K
# 1    ₹2,213K
# 2    ₹2,730K
# 3    ₹1,613K
# 4   ₹11,622K
# 5    ₹1,520K
# 6    ₹1,465K
# 7    ₹1,809K
# 8    ₹1,520K
# 9    ₹2,149K

# %%
avg_sal=driver.find_elements_by_xpath("//div[@class='col-2 d-none d-md-flex flex-row justify-content-end']/strong[1]")

# %%
avg_salary=[]
for i in avg_sal:
    if len(avg_salary)<10:
        avg_salary.append(i.text)
avg_salary
avg_salary = pd.DataFrame(avg_salary)
avg_salary.columns=['avg_salary']
avg_salary
#Average salaries of first 10 companies
# Out:
#     avg_salary
# 0   ₹ 6,11,228
# 1  ₹ 11,46,533
# 2   ₹ 8,97,795
# 3   ₹ 7,38,057
# 4  ₹ 12,39,781
# 5  ₹ 13,36,142
# 6   ₹ 8,15,192
# 7  ₹ 11,35,221
# 8  ₹ 11,44,243
# 9  ₹ 14,13,288

# %%
#rating?????

# %%
datascientistnoidasalary=pd.DataFrame({})
datascientistnoidasalary['Company_name']=company_name5['company_name']
datascientistnoidasalary['Min_salary']=min_salary['min_salary']
datascientistnoidasalary['Max_salary']=max_salary['max_salary']
datascientistnoidasalary['Avg_salary']=avg_salary['avg_salary']
datascientistnoidasalary
# min salary, max salary, company_name, Average salary and rating of the first 10 companies in Noida
# Out:
#                 Company_name Min_salary Max_salary   Avg_salary
# 0  Tata Consultancy Services      ₹343K    ₹1,095K   ₹ 6,11,228
# 1                  Accenture      ₹577K    ₹2,213K  ₹ 11,46,533
# 2                        IBM      ₹586K    ₹2,730K   ₹ 8,97,795
# 3         Ericsson-Worldwide      ₹355K    ₹1,613K   ₹ 7,38,057
# 4                  Delhivery      ₹450K   ₹11,622K  ₹ 12,39,781
# 5         UnitedHealth Group    ₹1,069K    ₹1,520K  ₹ 13,36,142
# 6         Valiance Solutions      ₹502K    ₹1,465K   ₹ 8,15,192
# 7              ZS Associates      ₹202K    ₹1,809K  ₹ 11,35,221
# 8                EXL Service      ₹575K    ₹1,520K  ₹ 11,44,243
# 9     Optum Global Solutions    ₹1,014K    ₹2,149K  ₹ 14,13,288

# %%
# rating??

# %% [markdown]
# Q6 : Scrape data of first 100 sunglasses listings on flipkart.com.

# %%
driver=webdriver.Chrome("chromedriver.exe")
url='https://www.flipkart.com/'
driver.get(url)

# %%
flipkart=driver.find_element_by_xpath("//input[@type='text']")
flipkart
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="a5cd8c03b9c62fb29aa22dc8cb78cda2", element="a3661ab3-5bf6-4d7f-98a3-7f4e71c2264f")>

# %%
flipkart.send_keys(Keys.CONTROL + "a")
flipkart.send_keys(Keys.DELETE)
#clears the search bar

# %%
flipkart.send_keys("sunglasses")

# %%
search_btn6=driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
search_btn6.click()#click on search button

# %%
brand=[]
for i in range(0,3):
    for j in driver.find_elements_by_xpath("//div[@class='_2WkVRV']"):
        if len(brand)<100:
            brand.append(j.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
        sleep(4)
    except NoSuchElementException:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][1]").click()
        sleep(4)
brand = pd.DataFrame(brand)
brand.columns=['brand']
brand
#first 100 sunglasses brands on flipkart.com
# Out:
#              brand
# 0     Singco India
# 1         bulgaria
# 2         Fastrack
# 3   ROZZETTA CRAFT
# 4           PIRASO
# ..             ...
# 95       ROYAL SON
# 96        Fastrack
# 97          GANSTA
# 98          GANSTA
# 99    Silver Kartz
#
# [100 rows x 1 columns]

# %%
search_btn6=driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
search_btn6.click() #clicks on search button

# %%
prddesc=[]
for i in range(0,3):
    for j in driver.find_elements_by_xpath("//a[@class='IRpwTa']"):
        if len(prddesc)<100:
            prddesc.append(j.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
        sleep(4)
    except NoSuchElementException:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][1]").click()
        sleep(4)
prddesc = pd.DataFrame(prddesc)
prddesc.columns=['prddesc']
prddesc
#first 100 sunglasses product description on flipkart.com
# Out:
#                                               prddesc
# 0   UV Protection, Riding Glasses, Others Aviator,...
# 1           Others Rectangular Sunglasses (Free Size)
# 2    UV Protection Rectangular Sunglasses (Free Size)
# 3   UV Protection Retro Square Sunglasses (Free Size)
# 4               UV Protection Aviator Sunglasses (54)
# ..                                                ...
# 95       UV Protection Aviator Sunglasses (Free Size)
# 96  Gradient, UV Protection Wayfarer Sunglasses (F...
# 97   UV Protection, Gradient Wayfarer Sunglasses (53)
# 98   UV Protection, Mirrored Wayfarer Sunglasses (53)
# 99      UV Protection Wayfarer Sunglasses (Free Size)
#
# [100 rows x 1 columns]

# %%
search_btn6=driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
search_btn6.click()#clicks on search button

# %%
price=[]
for i in range(0,3):
    for j in driver.find_elements_by_xpath("//div[@class='_30jeq3']"):
        if len(price)<100:
            price.append(j.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
        sleep(4)
    except NoSuchElementException:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][1]").click()
        sleep(4)
price = pd.DataFrame(price)
price.columns=['price']
price
#first 100 sunglasses price on flipkart.com
# Out:
#    price
# 0   ₹209
# 1   ₹449
# 2   ₹630
# 3   ₹499
# 4   ₹250
# ..   ...
# 95  ₹499
# 96  ₹682
# 97  ₹349
# 98  ₹199
# 99  ₹664
#
# [100 rows x 1 columns]

# %%
search_btn6=driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
search_btn6.click()#click all search button

# %%
discount=[]
for i in range(0,3):
    for j in driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']"):
        if len(discount)<100:
            discount.append(j.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
        sleep(4)
    except NoSuchElementException:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][1]").click()
        sleep(4)
discount = pd.DataFrame(discount)
discount.columns=['discount']
discount
#first 100 sunglasses discount % on flipkart.com
# Out:
#    discount
# 0   70% off
# 1   55% off
# 2   21% off
# 3   77% off
# 4   84% off
# ..      ...
# 95  61% off
# 96  14% off
# 97  82% off
# 98  80% off
# 99  66% off
#
# [100 rows x 1 columns]

# %%
pd.set_option("display.max_colwidth", -1) #displays whole column value

# %%
sunglasses=pd.DataFrame({})
sunglasses['Brand']=brand['brand']
sunglasses['Product_description']=prddesc['prddesc']
sunglasses['Price']=price['price']
sunglasses['Discount']=discount['discount']
sunglasses
#data of first 100 sunglasses listings on flipkart.com
# Out:
#              Brand  \
# 0   Singco India
# 1   bulgaria
# 2   Fastrack
# 3   ROZZETTA CRAFT
# 4   PIRASO
# ..     ...
# 95  ROYAL SON
# 96  Fastrack
# 97  GANSTA
# 98  GANSTA
# 99  Silver Kartz
#
#                                            Product_description Price Discount
# 0   UV Protection, Riding Glasses, Others Aviator, Wayfarer...  ₹209  70% off
# 1   Others Rectangular Sunglasses (Free Size)                   ₹449  55% off
# 2   UV Protection Rectangular Sunglasses (Free Size)            ₹630  21% off
# 3   UV Protection Retro Square Sunglasses (Free Size)           ₹499  77% off
# 4   UV Protection Aviator Sunglasses (54)                       ₹250  84% off
# ..                                    ...                        ...      ...
# 95  UV Protection Aviator Sunglasses (Free Size)                ₹499  61% off
# 96  Gradient, UV Protection Wayfarer Sunglasses (Free Size)     ₹682  14% off
# 97  UV Protection, Gradient Wayfarer Sunglasses (53)            ₹349  82% off
# ...

# %% [markdown]
# Q7: Scrape 100 reviews data from flipkart.com for iphone11 phone

# %%
driver=webdriver.Chrome("chromedriver.exe")
url='https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace'
driver.get(url)

# %%
search_btn7=driver.find_element_by_xpath("//div[@class='_3UAT2v _16PBlm']")
search_btn7.click() #click all reviews button

# %%
rate=[]
for i in range(0,11):
    for i in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']"):
        if len(rate)<100:
            rate.append(i.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
        sleep(4)
    except NoSuchElementException:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][1]").click()
        sleep(4)
rate = pd.DataFrame(rate)
rate.columns=['rate']
rate
#top 100 ratings of iphone 11
# Out:
#    rate
# 0   5
# 1   5
# 2   5
# 3   5
# 4   4
# .. ..
# 95  5
# 96  5
# 97  5
# 98  5
# 99  5
#
# [100 rows x 1 columns]

# %%
search_btn7=driver.find_element_by_xpath("//div[@class='_3UAT2v _16PBlm']")
search_btn7.click() #click all reviews button

# %%
review=[]
for j in range(0,11):
    for i in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        if len(review)<100:
            review.append(i.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
        sleep(4)
    except NoSuchElementException:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][1]").click()
        sleep(4)
review = pd.DataFrame(review)
review.columns=['review']
review
#top 100 Review_summary of iphone 11
# Out:
#                review
# 0   Brilliant
# 1   Perfect product!
# 2   Great product
# 3   Worth every penny
# 4   Good choice
# ..          ...
# 95  Excellent
# 96  Fabulous!
# 97  Wonderful
# 98  Fabulous!
# 99  Value-for-money
#
# [100 rows x 1 columns]

# %%
full_review=[]
for j in range(0,11):
    for i in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        if len(full_review)<100:
            try:
                driver.find_element_by_xpath("//span[@class='_1BWGvX']").click()
                full_review.append(i.text)
            
            except NoSuchElementException:
                full_review.append(i.text) 
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
        sleep(4)
    except NoSuchElementException:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][1]").click()
        sleep(4)
full_review = pd.DataFrame(full_review)
full_review.columns=['full_review']
full_review['full_review']=full_review['full_review'].str.replace('\n',' ')
full_review
#top 100 Full review of iphone 11
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
full_review=[]
for j in range(0,11):
    for i in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        if len(full_review)<100:
            try:
                driver.find_element_by_xpath("//span[@class='_1BWGvX']").click()
                full_review.append(i.text)
            
            except NoSuchElementException:
                full_review.append(i.text) 
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
        sleep(4)
    except NoSuchElementException:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][1]").click()
        sleep(4)
full_review = pd.DataFrame(full_review)
full_review.columns=['full_review']
full_review['full_review']=full_review['full_review'].str.replace('\n',' ')
full_review
#top 100 Full review of iphone 11
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
iphone11reviews=pd.DataFrame({})
iphone11reviews['Rating']=rate['rate']
iphone11reviews['Review']=review['review']
iphone11reviews['Full_review']=full_review['full_review']
iphone11reviews
# 100 reviews data from flipkart.com for iphone11
# Out:
#    Rating             Review  \
# 0   5      Brilliant
# 1   5      Perfect product!
# 2   5      Great product
# 3   5      Worth every penny
# 4   4      Good choice
# .. ..              ...
# 95  5      Excellent
# 96  5      Fabulous!
# 97  5      Wonderful
# 98  5      Fabulous!
# 99  5      Value-for-money
#
# ...

# %% [markdown]
# Q8: Scrape data for first 100 sneakers you find when you visit flipkart.com and
# search for “sneakers” in the search field.

# %%
driver=webdriver.Chrome("chromedriver.exe")
url='https://www.flipkart.com/'
driver.get(url)

# %%
flipkart2=driver.find_element_by_xpath("//input[@type='text']")
flipkart2
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="d6adb38135012be1b700be2f3224442a", element="b0f35629-58ee-43f7-b224-a8ca7d580386")>

# %%
flipkart2.send_keys(Keys.CONTROL + "a")
flipkart2.send_keys(Keys.DELETE)
#clearing text in search box

# %%
flipkart2.send_keys("sneakers") #enters "sneakers" in search bar

# %%
search_btn8=driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
search_btn8.click() #click on search button

# %%
brand1=[]
for i in range(0,3):
    for j in driver.find_elements_by_xpath("//div[@class='_2WkVRV']"):
        if len(brand1)<100:
            brand1.append(j.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
        sleep(4)
    except NoSuchElementException:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][1]").click()
        sleep(4)
brand1 = pd.DataFrame(brand1)
brand1.columns=['brand1']
brand1
# first 100 sneakers brand name
# Out:
#           brand1
# 0       PEHANOSA
# 1         DUCATI
# 2   Robbie jones
# 3       HOTSTYLE
# 4   Robbie jones
# ..           ...
# 95      Bersache
# 96      Wen Hawk
# 97       Airland
# 98      HOTSTYLE
# 99   casualpoint
#
# [100 rows x 1 columns]

# %%
brand1=[]
shoedesc=[]
price1=[]
discount1=[]


for i in range(0,3):
    for j in driver.find_elements_by_xpath("//div[@class='_2WkVRV']"):
        if len(brand1)<100:
            brand1.append(j.text)
    
    
    
    for j in driver.find_elements_by_xpath("//div[@class='_2B099V']/a"):
        if len(shoedesc)<200:
            shoedesc.append(j.get_attribute('title'))    
    
    
    
    for j in driver.find_elements_by_xpath("//div[@class='_30jeq3']"):
        if len(price1)<100:
            price1.append(j.text)
            
    
    
    for j in driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']"):
        if len(discount1)<100:
            discount1.append(j.text)            
          
    
    
    
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
        sleep(8)
    except NoSuchElementException:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][1]").click()
        sleep(8)
        
# first 100 sneakers brand name

brand1 = pd.DataFrame(brand1)
brand1.columns=['brand1']

# first 100 sneakers brand description

shoedesc = pd.DataFrame(shoedesc)
shoedesc.columns=['shoedesc']
shoedesc=shoedesc.iloc[range(0,len(shoedesc),2)] 
shoedesc=shoedesc.reset_index(drop=True)  #resetting index


# first 100 sneakers price

price1 = pd.DataFrame(price1)
price1.columns=['price1']

# first 100 sneakers discount

discount1 = pd.DataFrame(discount1)
discount1.columns=['discount1']

# %%
Sneakers=pd.DataFrame({})
Sneakers['Brand']=brand1['brand1']
Sneakers['Product_description']=shoedesc['shoedesc']
Sneakers['Price1']=price1['price1']
Sneakers['Discount1']=discount1['discount1']
Sneakers
#data of first 100 sneakers listings on flipkart.com
# Out:
#            Brand                                Product_description  Price1  \
# 0       PEHANOSA                                   Sneakers For Men    ₹499
# 1         DUCATI                                   Sneakers For Men  ₹1,924
# 2   Robbie jones     Casual Sneakers Shoes For Men Sneakers For Men    ₹379
# 3       HOTSTYLE                          Sneakers Sneakers For Men    ₹283
# 4   Robbie jones                                   Sneakers For Men    ₹474
# ..           ...                                                ...     ...
# 95     Englewood  White Shoes For Men | Casual White Laceups Sho...    ₹499
# 96       Airland                              shoe Sneakers For Men    ₹265
# 97      HOTSTYLE                          Sneakers Sneakers For Men    ₹299
# 98  Robbie jones                                   Sneakers For Men    ₹474
# 99        SHURAB  sneakers men sports shoes | Casual Sneakers Sh...    ₹399
#
#    Discount1
# 0    50% off
# 1    47% off
# ...

# %% [markdown]
# Q9: Go to the link - https://www.myntra.com/shoes
# Set Price filter to “Rs. 6649 to Rs. 13099” , Color filter to “Black”, as shown in
# the below image

# %%
driver=webdriver.Chrome("chromedriver.exe")
url='https://www.myntra.com/shoes'
driver.get(url)

# %%
filter_button=driver.find_element_by_xpath("(//div[@class='common-checkboxIndicator'])[16]")
filter_button.click() #clicks on '6589.0 TO 13059.0' price filter

# %%
filter_button=driver.find_element_by_xpath("(//div[@class='common-checkboxIndicator'])[18]")
filter_button.click() #clicks on 'Black' color filter

# %%
prodbrand1=[]
proddesc=[]
prodprice=[]

for i in range(0,3):
    
    for j in driver.find_elements_by_xpath("(//h3[@class='product-brand'])"):
        if len(prodbrand1)<100:
            prodbrand1.append(j.text)
    
    
    
    
    for j in driver.find_elements_by_xpath("(//h4[@class='product-product'])"):
        if len(proddesc)<100:
            proddesc.append(j.text)

    
    
    for j in driver.find_elements_by_xpath("(//div[@class='product-price'])/span[1]"):
        if len(prodprice)<100:
            prodprice.append(j.text)
    Next_button=driver.find_element_by_xpath("(//span[@class='pagination-arrowRight'])")
    Next_button.click()
    sleep(6)    

#first 100 shoes brand's on myntra.com in black color and price range of "6589.0 TO 13059.0"    
prodbrand1 = pd.DataFrame(prodbrand1)
prodbrand1.columns=['prodbrand1']

#first 100 shoes brand's product description on myntra.com in black color and price range of "6589.0 TO 13059.0"
proddesc = pd.DataFrame(proddesc)
proddesc.columns=['proddesc']

#first 100 shoes brand's price on myntra.com in black color and price range of "6589.0 TO 13059.0"
prodprice = pd.DataFrame(prodprice)
prodprice.columns=['prodprice']
prodprice['prodprice'] = prodprice['prodprice'].str[4:9]
prodprice['prodprice']=prodprice['prodprice'].str.replace('R','')

# %%
myntra=pd.DataFrame({})
myntra['Brand']=prodbrand1['prodbrand1']
myntra['Short Shoe description']=proddesc['proddesc']
myntra['Discount1']=prodprice['prodprice']
myntra
#data of first 100 shoes brands, Short Shoe descriptio and price of the shoe 
#on myntra.com in black color and price range of "6589.0 TO 13059.0"
# Out:
#                    Brand          Short Shoe description Discount1
# 0   Nike                  AIR ZOOM PEGASUS Running Shoes  11495
# 1   Nike                  Men AIR ZOOM Running Shoes      7721
# 2   Nike                  Men KD13 EP Basketball Shoes    12995
# 3   Nike                  Men React Infinity Running      11621
# 4   PUMA Motorsport       Unisex Mercedes Running Shoes   7999
# ..              ...                                 ...    ...
# 95  Heel & Buckle London  Women Leather Pumps             7192
# 96  Nike                  Men AIR ZOOM PEGASUS 38 Run     8995
# 97  Geox                  Women Solid Flatforms           6749
# 98  UNDER ARMOUR          Men Charged Bandit 6 Running    7649
# 99  Geox                  Women Leather Boat Shoes        8990
#
# [100 rows x 3 columns]

# %% [markdown]
# Q10: Go to webpage https://www.amazon.in/
#  Enter “Laptop” in the search field and then click the search icon.
#  Then set CPU Type filter to “Intel Core i7” and “Intel Core i9” as shown in the
# below image:

# %%
driver=webdriver.Chrome("chromedriver.exe")
url='https://www.amazon.in/'
driver.get(url)

# %%
search_job10=driver.find_element_by_id('twotabsearchtextbox')
search_job10 # keyowrd search bar
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="d729a699dc89cf065cfc162f0a51978f", element="00ba04c7-2159-414e-b4de-752e08c249e6")>

# %%
search_job10.send_keys('Laptop') #enters'Laptop' in keyword search bar

# %%
search=driver.find_element_by_id('nav-search-submit-button')
search.click() #clicks on search button

# %%
#intel core 17

filter_button=driver.find_elements_by_xpath("(//span[@class='a-size-base a-color-base'])")
for i in filter_button:
    if i.text=='Intel Core i7':
        i.click()
        break

# %%
laptitle=[]
for j in driver.find_elements_by_xpath("(//span[@class='a-size-medium a-color-base a-text-normal'])"):
    if len(laptitle)<10:
        laptitle.append(j.text)

laptitle = pd.DataFrame(laptitle)
laptitle.columns=['laptitle']
laptitle
#top 10 laptops for i7 in amazon.com
# Out:
#                                             laptitle
# 0  Lenovo IdeaPad Flex 5 11th Gen Intel Core i7 1...
# 1  Lenovo Yoga Slim 7 10th Gen Intel Core i7 14 i...
# 2  Mi Notebook Horizon Edition 14 Intel Core i5-1...
# 3  HP 2019 Probook 440 G6 14 Inch HD Business Lap...
# 4  Asus ROG Zephyrus S Ultra Slim Gaming Laptop, ...
# 5  Lenovo Legion 5Pi 10th Gen Intel Core i7 15.6"...
# 6  (Renewed) Dell Intel 4th Gen Core i7 4600U 14-...
# 7  Lenovo Legion Y540 Intel Core i7 9th Gen 15.6”...
# 8  Lenovo Yoga Slim 7i 11th Gen Intel Core i7 14"...
# 9  CUK VivoBook K571 by ASUS 15 Inch Gaming Lapto...

# %%
lapprice=[]
for j in driver.find_elements_by_xpath("(//span[@class='a-price-whole'])"):
    if len(lapprice)<10:
        lapprice.append(j.text)

lapprice = pd.DataFrame(lapprice)
lapprice.columns=['lapprice']
lapprice
#top 10 laptop's price for i7 in amazon.com
# Out:
#    lapprice
# 0    83,990
# 1    83,990
# 2    53,999
# 3  1,35,386
# 4  3,43,099
# 5  1,35,490
# 6    39,999
# 7    68,990
# 8    97,990
# 9  1,44,643

# %%
ratingurli7=[] #scraping all urls of first 10 i7 laptops
for i in driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']/a"):
    if len(ratingurli7)<10:
        ratingurli7.append(i.get_attribute('href'))
ratingurli7
# Out:
# ['https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_computers_sr_pg1_1?ie=UTF8&adId=A04686372EO1LCBF9AV16&url=%2FLenovo-Touchscreen-Fingerprint-Graphite-82HS0092IN%2Fdp%2FB08WRZQBQ6%2Fref%3Dsr_1_1_sspa%3Fdchild%3D1%26keywords%3DLaptop%26qid%3D1621656769%26refinements%3Dp_n_feature_thirteen_browse-bin%253A12598163031%26rnid%3D12598141031%26s%3Dcomputers%26sr%3D1-1-spons%26psc%3D1&qualifier=1621656769&id=1948385856452844&widgetName=sp_atf',
#  'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_computers_sr_pg1_1?ie=UTF8&adId=A0372319347VE4FKU20UM&url=%2FLenovo-Laptop-Windows-Graphics-82A1009KIN%2Fdp%2FB087D38ZP4%2Fref%3Dsr_1_2_sspa%3Fdchild%3D1%26keywords%3DLaptop%26qid%3D1621656769%26refinements%3Dp_n_feature_thirteen_browse-bin%253A12598163031%26rnid%3D12598141031%26s%3Dcomputers%26sr%3D1-2-spons%26psc%3D1&qualifier=1621656769&id=1948385856452844&widgetName=sp_atf',
# ...

# %%
lapratingi7=[]
for i in ratingurli7:
    url=i
    driver.get(url)
    sleep(4)
    try:
        ratingi7=driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']")
        lapratingi7.append(ratingi7.text)
    except NoSuchElementException:
        lapratingi7.append('None')
lapratingi7 = pd.DataFrame(lapratingi7)            
lapratingi7.columns=['laprating']
lapratingi7
# Out:
#       laprating
# 0    4 out of 5
# 1  3.2 out of 5
# 2  4.4 out of 5
# 3    5 out of 5
# 4  4.3 out of 5
# 5  4.3 out of 5
# 6          None
# 7  4.1 out of 5
# 8          None
# 9  4.7 out of 5

# %%
laptopi7=pd.DataFrame({})
laptopi7['Title']=laptitle['laptitle']
laptopi7['Price']=lapprice['lapprice']
laptopi7['Rating']=lapratingi7['laprating']
laptopi7
#first 10 i7 laptop's Title, price and ratings
# Out:
#                                                Title     Price        Rating
# 0  Lenovo IdeaPad Flex 5 11th Gen Intel Core i7 1...    83,990    4 out of 5
# 1  Lenovo Yoga Slim 7 10th Gen Intel Core i7 14 i...    83,990  3.2 out of 5
# 2  Mi Notebook Horizon Edition 14 Intel Core i5-1...    53,999  4.4 out of 5
# 3  HP 2019 Probook 440 G6 14 Inch HD Business Lap...  1,35,386    5 out of 5
# 4  Asus ROG Zephyrus S Ultra Slim Gaming Laptop, ...  3,43,099  4.3 out of 5
# 5  Lenovo Legion 5Pi 10th Gen Intel Core i7 15.6"...  1,35,490  4.3 out of 5
# 6  (Renewed) Dell Intel 4th Gen Core i7 4600U 14-...    39,999          None
# 7  Lenovo Legion Y540 Intel Core i7 9th Gen 15.6”...    68,990  4.1 out of 5
# 8  Lenovo Yoga Slim 7i 11th Gen Intel Core i7 14"...    97,990          None
# 9  CUK VivoBook K571 by ASUS 15 Inch Gaming Lapto...  1,44,643  4.7 out of 5

# %% [markdown]
# First 10 i9 laptop's Title, price and ratings

# %%
driver=webdriver.Chrome("chromedriver.exe")
url='https://www.amazon.in/'
driver.get(url)

# %%
search_job11=driver.find_element_by_id('twotabsearchtextbox')
search_job11 # keyowrd search bar
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="a7f3116fabaa377c0bd6e3f383c74b5e", element="514e2b66-f0e0-4447-a80a-8e1fbaaf544f")>

# %%
search_job11.send_keys('Laptop') #enters'Laptop' in keyword search bar

# %%
search2=driver.find_element_by_id('nav-search-submit-button')
search2.click() #clicks on search button

# %%
#intel core 19

filter_button=driver.find_elements_by_xpath("(//span[@class='a-size-base a-color-base'])")
for i in filter_button:
    if i.text=='Intel Core i9':
        i.click()
        break

# %%
laptitle1=[]
for j in driver.find_elements_by_xpath("(//span[@class='a-size-medium a-color-base a-text-normal'])"):
    if len(laptitle1)<10:
        laptitle1.append(j.text)

laptitle1 = pd.DataFrame(laptitle1)
laptitle1.columns=['laptitle']
laptitle1
#top 10 laptops for i9 in amazon.com
# Out:
#                                             laptitle
# 0  ASUS ZenBook Pro Duo Intel Core i9-10980HK 10t...
# 1  ASUS ROG G703GI-E5148T 17.3" (43.94 cms) FHD 1...
# 2  Dell XPS 9570 15.6" (39.62cms) UHD Laptop (8th...
# 3  Lenovo Legion 7 10th Gen Intel Core i9 15.6 in...
# 4  ASUS ROG Zephyrus Duo 15, 15.6" FHD 300Hz/3ms,...
# 5  ASUS ZenBook Pro Duo UX581GV-H2041T Intel Core...
# 6  ASUS ROG Strix Scar 17 (2020), 17.3" FHD 300Hz...
# 7  ASUS ROG Strix Scar 15 (2020), 15.6" FHD 300Hz...
# 8  (Renewed) Dell XPS 9570 Laptop|i9-8950HK|32GB ...
# 9  Dell G7 7500 15.6inch FHD 300 Hz Display Gamin...

# %%
lapprice1=[]
for j in driver.find_elements_by_xpath("(//span[@class='a-price-whole'])"):
    if len(lapprice1)<10:
        lapprice1.append(j.text)

lapprice1 = pd.DataFrame(lapprice1)
lapprice1.columns=['lapprice']
lapprice1
#top 10 laptop's price for i9 in amazon.com
# Out:
#    lapprice
# 0  2,99,325
# 1  4,13,890
# 2  2,48,790
# 3  2,62,990
# 4  2,66,990
# 5  2,79,990
# 6  2,77,490
# 7  2,15,990
# 8  1,89,900
# 9  2,00,690

# %%
ratingurli9=[] #scraping all urls of first 10 job's full description
for i in driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']/a"):
    if len(ratingurli9)<10:
        ratingurli9.append(i.get_attribute('href'))
ratingurli9
# Out:
# ['https://www.amazon.in/ASUS-i9-10980HK-Touchscreen-Celestial-UX581LV-H2035T/dp/B08CHDLVT1/ref=sr_1_1?dchild=1&keywords=Laptop&qid=1621657856&refinements=p_n_feature_thirteen_browse-bin%3A16757432031&rnid=12598141031&s=computers&sr=1-1',
#  'https://www.amazon.in/Asus-G703GI-E5148T-17-3-inch-i9-8950HK-Processor/dp/B07GRCW51K/ref=sr_1_2?dchild=1&keywords=Laptop&qid=1621657856&refinements=p_n_feature_thirteen_browse-bin%3A16757432031&rnid=12598141031&s=computers&sr=1-2',
#  'https://www.amazon.in/Dell-9570-15-6-inch-i9-8950HK-Integrated/dp/B08C5FMBLB/ref=sr_1_3?dchild=1&keywords=Laptop&qid=1621657856&refinements=p_n_feature_thirteen_browse-bin%3A16757432031&rnid=12598141031&s=computers&sr=1-3',
#  'https://www.amazon.in/Lenovo-Legion-Windows-Graphics-81YU006HIN/dp/B08GG9RZJC/ref=sr_1_4?dchild=1&keywords=Laptop&qid=1621657856&refinements=p_n_feature_thirteen_browse-bin%3A16757432031&rnid=12598141031&s=computers&sr=1-4',
# ...

# %%
lapratingi9=[]
for i in ratingurli9:
    url=i
    driver.get(url)
    sleep(4)
    try:
        ratingi9=driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']")
        lapratingi9.append(ratingi9.text)
    except NoSuchElementException:
        lapratingi9.append('None')
lapratingi9 = pd.DataFrame(lapratingi9)            
lapratingi9.columns=['laprating']
lapratingi9
# Out:
#       laprating
# 0  3.8 out of 5
# 1  3.7 out of 5
# 2  2.4 out of 5
# 3  3.7 out of 5
# 4          None
# 5  3.9 out of 5
# 6  4.8 out of 5
# 7  4.2 out of 5
# 8          None
# 9  3.4 out of 5

# %%
laptopi9=pd.DataFrame({})
laptopi9['Title']=laptitle1['laptitle']
laptopi9['Price']=lapprice1['lapprice']
laptopi9['Rating']=lapratingi9['laprating']
laptopi9
#first 10 i9 laptop's Title, price and ratings
# Out:
#                                                Title     Price        Rating
# 0  ASUS ZenBook Pro Duo Intel Core i9-10980HK 10t...  2,99,325  3.8 out of 5
# 1  ASUS ROG G703GI-E5148T 17.3" (43.94 cms) FHD 1...  4,13,890  3.7 out of 5
# 2  Dell XPS 9570 15.6" (39.62cms) UHD Laptop (8th...  2,48,790  2.4 out of 5
# 3  Lenovo Legion 7 10th Gen Intel Core i9 15.6 in...  2,62,990  3.7 out of 5
# 4  ASUS ROG Zephyrus Duo 15, 15.6" FHD 300Hz/3ms,...  2,66,990          None
# 5  ASUS ZenBook Pro Duo UX581GV-H2041T Intel Core...  2,79,990  3.9 out of 5
# 6  ASUS ROG Strix Scar 17 (2020), 17.3" FHD 300Hz...  2,77,490  4.8 out of 5
# 7  ASUS ROG Strix Scar 15 (2020), 15.6" FHD 300Hz...  2,15,990  4.2 out of 5
# 8  (Renewed) Dell XPS 9570 Laptop|i9-8950HK|32GB ...  1,89,900          None
# 9  Dell G7 7500 15.6inch FHD 300 Hz Display Gamin...  2,00,690  3.4 out of 5
